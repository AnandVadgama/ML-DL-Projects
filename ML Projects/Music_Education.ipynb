# %%
import numpy as py
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
music = pd.read_csv('music_education_dataset.csv')
music.head()
# Out:
#   Student_ID  Age  Gender   Class_Level   Accuracy     Rhythm       Tempo  \
# 0       S001   12  Female  Intermediate  71.053342  94.391587  142.863298
# 1       S002   11    Male      Advanced  77.352080  72.841144  142.035970
# 2       S003   13  Female  Intermediate  93.776395  94.781988  110.298237
# 3       S004   16  Female  Intermediate  77.101801  90.951063  100.547725
# 4       S005   11    Male      Beginner  80.318380  72.558753  175.980186
#
#    Pitch_Accuracy    Duration     Volume  ...  Stress_Level  Engagement_Level  \
# 0       88.828261  336.481857  86.428281  ...            10                 5
# 1       87.043906  371.244505  57.301702  ...             2                 4
# 2       92.283188  481.536745  83.494998  ...             3                 1
# 3       99.515410  259.091623  61.625075  ...             7                 5
# 4       85.663472  200.832085  71.774177  ...             5                10
#
# ...

# %%
music.shape
# Out:
# (100, 22)

# %%
music.describe()
# Out:
#               Age    Accuracy      Rhythm       Tempo  Pitch_Accuracy  \
# count  100.000000  100.000000  100.000000  100.000000      100.000000
# mean    13.530000   83.696677   85.559333  136.724994       90.540340
# std      2.337464    8.809481    8.506669   25.747350        5.861590
# min     10.000000   70.025969   71.051253   90.403546       80.296075
# 25%     11.750000   75.655089   78.153848  114.754370       85.703179
# 50%     13.500000   82.739047   85.571346  138.848089       90.328815
# 75%     16.000000   92.121121   92.974344  156.049853       95.379560
# max     17.000000   99.621783   99.837140  178.266168       99.954110
#
#          Duration      Volume  Heart_Rate  Blood_Pressure  Stress_Level  \
# count  100.000000  100.000000  100.000000      100.000000    100.000000
# mean   366.513294   74.557013   80.995748      120.106621      5.670000
# std    127.509080   13.546720   11.280124        6.037906      2.693258
# ...

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           100 non-null    object
#  1   Age                  100 non-null    int64
#  2   Gender               100 non-null    object
#  3   Class_Level          100 non-null    object
#  4   Accuracy             100 non-null    float64
#  5   Rhythm               100 non-null    float64
#  6   Tempo                100 non-null    float64
#  7   Pitch_Accuracy       100 non-null    float64
#  8   Duration             100 non-null    float64
#  9   Volume               100 non-null    float64
#  10  Heart_Rate           100 non-null    float64
#  11  Blood_Pressure       100 non-null    float64
#  12  Stress_Level         100 non-null    int64
#  13  Engagement_Level     100 non-null    int64
#  14  Focus_Time           100 non-null    float64
# ...

# %%
music.isnull().sum()
# Out:
# Student_ID             0
# Age                    0
# Gender                 0
# Class_Level            0
# Accuracy               0
# Rhythm                 0
# Tempo                  0
# Pitch_Accuracy         0
# Duration               0
# Volume                 0
# Heart_Rate             0
# Blood_Pressure         0
# Stress_Level           0
# Engagement_Level       0
# Focus_Time             0
# Behavioral_Patterns    0
# Performance_Score      0
# Skill_Development      0
# Engagement_Score       0
# Timestamp              0
# Lesson_Type            0
# Instrument_Type        0
# dtype: int64

# %%
music.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Class_Level', 'Accuracy', 'Rhythm',
#        'Tempo', 'Pitch_Accuracy', 'Duration', 'Volume', 'Heart_Rate',
#        'Blood_Pressure', 'Stress_Level', 'Engagement_Level', 'Focus_Time',
#        'Behavioral_Patterns', 'Performance_Score', 'Skill_Development',
#        'Engagement_Score', 'Timestamp', 'Lesson_Type', 'Instrument_Type'],
#       dtype='object')

# %%
music.dtypes
# Out:
# Student_ID              object
# Age                      int64
# Gender                  object
# Class_Level             object
# Accuracy               float64
# Rhythm                 float64
# Tempo                  float64
# Pitch_Accuracy         float64
# Duration               float64
# Volume                 float64
# Heart_Rate             float64
# Blood_Pressure         float64
# Stress_Level             int64
# Engagement_Level         int64
# Focus_Time             float64
# Behavioral_Patterns      int64
# Performance_Score      float64
# Skill_Development        int64
# Engagement_Score       float64
# Timestamp               object
# Lesson_Type             object
# Instrument_Type         object
# dtype: object

# %%
music.fillna(0,inplace=True)
music.dropna(inplace=True)

# %%
music.rename(columns={"Duration": "Time_Span"}, inplace=True)

# %%
music.dtypes
# Out:
# Student_ID              object
# Age                      int64
# Gender                  object
# Class_Level             object
# Accuracy               float64
# Rhythm                 float64
# Tempo                  float64
# Pitch_Accuracy         float64
# Time_Span              float64
# Volume                 float64
# Heart_Rate             float64
# Blood_Pressure         float64
# Stress_Level             int64
# Engagement_Level         int64
# Focus_Time             float64
# Behavioral_Patterns      int64
# Performance_Score      float64
# Skill_Development        int64
# Engagement_Score       float64
# Timestamp               object
# Lesson_Type             object
# Instrument_Type         object
# dtype: object

# %%
Intermediate_music= music[music['Class_Level']== 'Intermediate']

# %%
music.head()
# Out:
#   Student_ID  Age  Gender   Class_Level   Accuracy     Rhythm       Tempo  \
# 0       S001   12  Female  Intermediate  71.053342  94.391587  142.863298
# 1       S002   11    Male      Advanced  77.352080  72.841144  142.035970
# 2       S003   13  Female  Intermediate  93.776395  94.781988  110.298237
# 3       S004   16  Female  Intermediate  77.101801  90.951063  100.547725
# 4       S005   11    Male      Beginner  80.318380  72.558753  175.980186
#
#    Pitch_Accuracy   Time_Span     Volume  ...  Stress_Level  Engagement_Level  \
# 0       88.828261  336.481857  86.428281  ...            10                 5
# 1       87.043906  371.244505  57.301702  ...             2                 4
# 2       92.283188  481.536745  83.494998  ...             3                 1
# 3       99.515410  259.091623  61.625075  ...             7                 5
# 4       85.663472  200.832085  71.774177  ...             5                10
#
# ...

# %%
Intermediate_music.iloc[0:]
# Out:
#    Student_ID  Age  Gender   Class_Level   Accuracy     Rhythm       Tempo  \
# 0        S001   12  Female  Intermediate  71.053342  94.391587  142.863298
# 2        S003   13  Female  Intermediate  93.776395  94.781988  110.298237
# 3        S004   16  Female  Intermediate  77.101801  90.951063  100.547725
# 5        S006   15    Male  Intermediate  96.837773  94.942365  169.611288
# 10       S011   10  Female  Intermediate  93.214844  75.946321  100.773306
# 14       S015   12    Male  Intermediate  92.999352  75.343144  130.152969
# 20       S021   10  Female  Intermediate  75.289808  83.539399  103.090913
# 21       S022   10  Female  Intermediate  93.852224  99.356185  152.372718
# 25       S026   13    Male  Intermediate  78.641138  89.525960  127.517004
# 27       S028   11    Male  Intermediate  90.076114  79.777382  132.569280
# 30       S031   12  Female  Intermediate  82.661020  75.621358  101.542663
# ...

# %%
music.drop_duplicates(inplace=True)

# %%
music.shape
# Out:
# (100, 22)

# %%
music['New_Column'] = music['Accuracy'] / music['Time_Span']

# %%
music.head()
# Out:
#   Student_ID  Age  Gender   Class_Level   Accuracy     Rhythm       Tempo  \
# 0       S001   12  Female  Intermediate  71.053342  94.391587  142.863298
# 1       S002   11    Male      Advanced  77.352080  72.841144  142.035970
# 2       S003   13  Female  Intermediate  93.776395  94.781988  110.298237
# 3       S004   16  Female  Intermediate  77.101801  90.951063  100.547725
# 4       S005   11    Male      Beginner  80.318380  72.558753  175.980186
#
#    Pitch_Accuracy   Time_Span     Volume  ...  Engagement_Level  Focus_Time  \
# 0       88.828261  336.481857  86.428281  ...                 5  453.536655
# 1       87.043906  371.244505  57.301702  ...                 4  474.173715
# 2       92.283188  481.536745  83.494998  ...                 1  463.233013
# 3       99.515410  259.091623  61.625075  ...                 5  346.641786
# 4       85.663472  200.832085  71.774177  ...                10  150.255627
#
#    Behavioral_Patterns  Performance_Score  Skill_Development  \
# ...

# %%
music['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
music['Age'].unique()
# Out:
# array([12, 11, 13, 16, 15, 14, 10, 17])

# %%
music['Instrument_Type'].unique()
# Out:
# array(['Guitar', 'Violin', 'Piano'], dtype=object)

# %%
music['Instrument_Type'].value_counts()
# Out:
# Instrument_Type
# Guitar    41
# Piano     33
# Violin    26
# Name: count, dtype: int64

# %%
music.groupby('Class_Level')['Accuracy'].mean()
# Out:
# Class_Level
# Advanced        82.538402
# Beginner        84.173176
# Intermediate    84.299199
# Name: Accuracy, dtype: float64

# %%
#matplotlib

# %%
music['Accuracy'].hist()
# Out:
# <Axes: >

# %%
x = music['Accuracy']

# %%
x
# Out:
# 0     71.053342
# 1     77.352080
# 2     93.776395
# 3     77.101801
# 4     80.318380
#         ...
# 95    93.175135
# 96    74.173087
# 97    82.208138
# 98    75.662301
# 99    76.159450
# Name: Accuracy, Length: 100, dtype: float64

# %%
y = music['Pitch_Accuracy']

# %%
y
# Out:
# 0     88.828261
# 1     87.043906
# 2     92.283188
# 3     99.515410
# 4     85.663472
#         ...
# 95    92.019817
# 96    84.441934
# 97    86.574064
# 98    85.983289
# 99    91.154487
# Name: Pitch_Accuracy, Length: 100, dtype: float64

# %%
plt.scatter(x,y,color = 'red')
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()
